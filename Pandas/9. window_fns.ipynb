# %% [markdown]
# # ================ WINDOW FUNCTIONS ================

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({
    "store": ["A","A","A","A","B","B","B","B"],
    "date": pd.date_range("2024-01-01", periods=8, freq="D"),
    "sales": [10, 12, 9, 13, 20, 18, 25, 22]
})
df
# Out:
#   store       date  sales
# 0     A 2024-01-01     10
# 1     A 2024-01-02     12
# 2     A 2024-01-03      9
# 3     A 2024-01-04     13
# 4     B 2024-01-05     20
# 5     B 2024-01-06     18
# 6     B 2024-01-07     25
# 7     B 2024-01-08     22

# %%
df = pd.DataFrame({
    "store": ["A","A","A","A","B","B","B","B"],
    "date": pd.date_range("2024-01-01", periods=8, freq="D"),
    "sales": [10, 12, 9, 13, 20, 18, 25, 22]
}).sort_values(["store","date"]).reset_index()
df
# Out:
#    index store       date  sales
# 0      0     A 2024-01-01     10
# 1      1     A 2024-01-02     12
# 2      2     A 2024-01-03      9
# 3      3     A 2024-01-04     13
# 4      4     B 2024-01-05     20
# 5      5     B 2024-01-06     18
# 6      6     B 2024-01-07     25
# 7      7     B 2024-01-08     22

# %%
df = pd.DataFrame({
    "store": ["A","A","A","A","B","B","B","B"],
    "date": pd.date_range("2024-01-01", periods=8, freq="D"),
    "sales": [10, 12, 9, 13, 20, 18, 25, 22]
}).sort_values(["store","date"]).reset_index(drop=True)
df
# Out:
#   store       date  sales
# 0     A 2024-01-01     10
# 1     A 2024-01-02     12
# 2     A 2024-01-03      9
# 3     A 2024-01-04     13
# 4     B 2024-01-05     20
# 5     B 2024-01-06     18
# 6     B 2024-01-07     25
# 7     B 2024-01-08     22

# %% [markdown]
# ## ----------- ROLLING WINDOWS -----------
# > Provide rolling window calculations.
#
# > rolling = “look back N rows”
#
# > Problem: Rolling drops old rows abruptly.
#
# > DataFrame.rolling(window, min_periods=None, center=False, win_type=None, on=None, axis=<no_default>, closed=None, step=None, method='single')

# %% [markdown]
# ### Fixed-size window
#
# > Fixed-size moving window

# %%
# Rolling sum with a window length of 3 observations
df["rolling_sum_3"] = df["sales"].rolling(window=3).sum()
df
# Out:
#   store       date  sales  rolling_sum_3
# 0     A 2024-01-01     10            NaN
# 1     A 2024-01-02     12            NaN
# 2     A 2024-01-03      9           31.0
# 3     A 2024-01-04     13           34.0
# 4     B 2024-01-05     20           42.0
# 5     B 2024-01-06     18           51.0
# 6     B 2024-01-07     25           63.0
# 7     B 2024-01-08     22           65.0

# %%
# Rolling sum with a window length of 3 observations, but only needs a minimum of 1 observation to calculate a value.
df["rolling_sum_1"] = df["sales"].rolling(window=3, min_periods=1).sum()
df
# Out:
#   store       date  sales  rolling_sum_3  rolling_sum_1
# 0     A 2024-01-01     10            NaN           10.0
# 1     A 2024-01-02     12            NaN           22.0
# 2     A 2024-01-03      9           31.0           31.0
# 3     A 2024-01-04     13           34.0           34.0
# 4     B 2024-01-05     20           42.0           42.0
# 5     B 2024-01-06     18           51.0           51.0
# 6     B 2024-01-07     25           63.0           63.0
# 7     B 2024-01-08     22           65.0           65.0

# %% [markdown]
# ##### closed parameter ❓❓❓❓

# %%
# Rolling sum with a window length of 3 observations, but only needs a minimum of 1 observation to calculate a value.
df["rolling_sum_1"] = df["sales"].rolling(window=3, min_periods=1, closed='left').sum()
df
# Out:
#   store       date  sales  rolling_sum_3  rolling_sum_1
# 0     A 2024-01-01     10            NaN            NaN
# 1     A 2024-01-02     12            NaN           10.0
# 2     A 2024-01-03      9           31.0           22.0
# 3     A 2024-01-04     13           34.0           31.0
# 4     B 2024-01-05     20           42.0           34.0
# 5     B 2024-01-06     18           51.0           42.0
# 6     B 2024-01-07     25           63.0           51.0
# 7     B 2024-01-08     22           65.0           63.0

# %%
# Rolling sum with a window length of 3 observations, minimum of 1 observation to calculate a value, and a step of 2.
df["rolling_sum_1_2step"] = df["sales"].rolling(window=3, min_periods=1, step=2).sum()
df
# Out:
#   store       date  sales  rolling_sum_3  rolling_sum_1  rolling_sum_1_2step
# 0     A 2024-01-01     10            NaN            NaN                 10.0
# 1     A 2024-01-02     12            NaN           10.0                  NaN
# 2     A 2024-01-03      9           31.0           22.0                 31.0
# 3     A 2024-01-04     13           34.0           31.0                  NaN
# 4     B 2024-01-05     20           42.0           34.0                 42.0
# 5     B 2024-01-06     18           51.0           42.0                  NaN
# 6     B 2024-01-07     25           63.0           51.0                 63.0
# 7     B 2024-01-08     22           65.0           63.0                  NaN

# %%
# # Per store (reset index trick to align results)
# df["rolling_sum_store"] = (
#     df.groupby("store")["sales"]
#       .rolling(window=3, min_periods=1)
#       .sum()
# )
# df  # ❌❌ TypeError: incompatible index of inserted column with frame index ❌❌

# %%
# Per store (reset index trick to align results)
df["rolling_sum_store"] = (
    df.groupby("store")["sales"]
      .rolling(window=3, min_periods=1)
      .sum()
      .reset_index(level=0, drop=True)
)
df
# Out:
#   store       date  sales  rolling_sum_3  rolling_sum_1  rolling_sum_1_2step  \
# 0     A 2024-01-01     10            NaN            NaN                 10.0
# 1     A 2024-01-02     12            NaN           10.0                  NaN
# 2     A 2024-01-03      9           31.0           22.0                 31.0
# 3     A 2024-01-04     13           34.0           31.0                  NaN
# 4     B 2024-01-05     20           42.0           34.0                 42.0
# 5     B 2024-01-06     18           51.0           42.0                  NaN
# 6     B 2024-01-07     25           63.0           51.0                 63.0
# 7     B 2024-01-08     22           65.0           63.0                  NaN
#
#    rolling_sum_store
# 0               10.0
# 1               22.0
# 2               31.0
# 3               34.0
# 4               20.0
# 5               38.0
# 6               63.0
# 7               65.0

# %%
# OR Using transform. It applies your function per group and returns a result aligned to the original index
df["roll3_mean_store"] = (
    df.sort_values(["store", "date"])               
      .groupby("store")["sales"]
      .transform(lambda s: s.rolling(3, min_periods=1).mean())
)
df
# Out:
#   store       date  sales  rolling_sum_3  rolling_sum_1  rolling_sum_1_2step  \
# 0     A 2024-01-01     10            NaN            NaN                 10.0
# 1     A 2024-01-02     12            NaN           10.0                  NaN
# 2     A 2024-01-03      9           31.0           22.0                 31.0
# 3     A 2024-01-04     13           34.0           31.0                  NaN
# 4     B 2024-01-05     20           42.0           34.0                 42.0
# 5     B 2024-01-06     18           51.0           42.0                  NaN
# 6     B 2024-01-07     25           63.0           51.0                 63.0
# 7     B 2024-01-08     22           65.0           63.0                  NaN
#
#    rolling_sum_store  roll3_mean_store
# 0               10.0         10.000000
# 1               22.0         11.000000
# 2               31.0         10.333333
# 3               34.0         11.333333
# 4               20.0         20.000000
# 5               38.0         19.000000
# 6               63.0         21.000000
# 7               65.0         21.666667

# %% [markdown]
# #### Time-based rolling

# %%
# for last 2 days
df["time_based_sum_2D"] = (
    df.groupby("store")                               # DataFrameGroupBy
      .rolling("2D", on="date")["sales"]              # use 'on' to point to the time column
      .sum()
      .reset_index(level=0, drop=True)              
)
df
# Out:
#   store       date  sales  rolling_sum_3  rolling_sum_1  rolling_sum_1_2step  \
# 0     A 2024-01-01     10            NaN            NaN                 10.0
# 1     A 2024-01-02     12            NaN           10.0                  NaN
# 2     A 2024-01-03      9           31.0           22.0                 31.0
# 3     A 2024-01-04     13           34.0           31.0                  NaN
# 4     B 2024-01-05     20           42.0           34.0                 42.0
# 5     B 2024-01-06     18           51.0           42.0                  NaN
# 6     B 2024-01-07     25           63.0           51.0                 63.0
# 7     B 2024-01-08     22           65.0           63.0                  NaN
#
#    rolling_sum_store  roll3_mean_store  time_based_sum_2D
# 0               10.0         10.000000                NaN
# 1               22.0         11.000000                NaN
# 2               31.0         10.333333                NaN
# 3               34.0         11.333333                NaN
# 4               20.0         20.000000                NaN
# 5               38.0         19.000000                NaN
# 6               63.0         21.000000                NaN
# 7               65.0         21.666667                NaN

# %%
# OR The Transform Version -
df = df.sort_values(["store", "date"])
df["sum_2D"] = (
    df.groupby("store")
      .apply(lambda g: g.rolling("2D", on="date")["sales"].sum())
      .reset_index(level=0, drop=True)
)
df
# Out:
# /tmp/ipykernel_67462/2021156094.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda g: g.rolling("2D", on="date")["sales"].sum())
#   store       date  sales  rolling_sum_3  rolling_sum_1  rolling_sum_1_2step  \
# 0     A 2024-01-01     10            NaN            NaN                 10.0
# 1     A 2024-01-02     12            NaN           10.0                  NaN
# 2     A 2024-01-03      9           31.0           22.0                 31.0
# 3     A 2024-01-04     13           34.0           31.0                  NaN
# 4     B 2024-01-05     20           42.0           34.0                 42.0
# 5     B 2024-01-06     18           51.0           42.0                  NaN
# 6     B 2024-01-07     25           63.0           51.0                 63.0
# 7     B 2024-01-08     22           65.0           63.0                  NaN
#
#    rolling_sum_store  roll3_mean_store  time_based_sum_2D  sum_2D
# 0               10.0         10.000000                NaN    10.0
# 1               22.0         11.000000                NaN    22.0
# 2               31.0         10.333333                NaN    21.0
# 3               34.0         11.333333                NaN    22.0
# 4               20.0         20.000000                NaN    20.0
# 5               38.0         19.000000                NaN    38.0
# 6               63.0         21.000000                NaN    43.0
# 7               65.0         21.666667                NaN    47.0

# %% [markdown]
# ## ----------- EXPANDING -----------
# > Running / Cumulative:- expanding = “look back ALL rows so far”
#
# > Expands from the start of data until the current row
#
# > Provide expanding window calculations.
#
# > Problem:- Expanding gives equal weight to all past rows.
#
# > DataFrame.expanding(min_periods=1, axis=<no_default>, method='single')

# %%
dff = pd.DataFrame({"B": [0, 1, 2, np.nan, 4]})
dff
# Out:
#      B
# 0  0.0
# 1  1.0
# 2  2.0
# 3  NaN
# 4  4.0

# %%
dff.expanding(1).sum()
# Out:
#      B
# 0  0.0
# 1  1.0
# 2  3.0
# 3  3.0
# 4  7.0

# %%
dff.expanding(min_periods=2).sum()
# Out:
#      B
# 0  NaN
# 1  1.0
# 2  3.0
# 3  3.0
# 4  7.0

# %%
df = pd.DataFrame({
    "store": ["A","A","A","A","B","B","B","B"],
    "date": pd.date_range("2024-01-01", periods=8, freq="D"),
    "sales": [10, 12, 9, 13, 20, 18, 25, 22]
}).sort_values(["store","date"]).reset_index(drop=True)
df
# Out:
#   store       date  sales
# 0     A 2024-01-01     10
# 1     A 2024-01-02     12
# 2     A 2024-01-03      9
# 3     A 2024-01-04     13
# 4     B 2024-01-05     20
# 5     B 2024-01-06     18
# 6     B 2024-01-07     25
# 7     B 2024-01-08     22

# %%
# Cumulative sum
df["expanding_sum"] = df["sales"].expanding().sum()
df
# Out:
#   store       date  sales  expanding_sum
# 0     A 2024-01-01     10           10.0
# 1     A 2024-01-02     12           22.0
# 2     A 2024-01-03      9           31.0
# 3     A 2024-01-04     13           44.0
# 4     B 2024-01-05     20           64.0
# 5     B 2024-01-06     18           82.0
# 6     B 2024-01-07     25          107.0
# 7     B 2024-01-08     22          129.0

# %%
# OR (but without decimal):
df["cum_sum"] = df["sales"].cumsum()
df
# Out:
#   store       date  sales  expanding_sum  cum_sum
# 0     A 2024-01-01     10           10.0       10
# 1     A 2024-01-02     12           22.0       22
# 2     A 2024-01-03      9           31.0       31
# 3     A 2024-01-04     13           44.0       44
# 4     B 2024-01-05     20           64.0       64
# 5     B 2024-01-06     18           82.0       82
# 6     B 2024-01-07     25          107.0      107
# 7     B 2024-01-08     22          129.0      129

# %%
df["exp_mean_min2"] = df["sales"].expanding(min_periods=2).mean()
df
# Out:
#   store       date  sales  expanding_sum  cum_sum  exp_mean_min2
# 0     A 2024-01-01     10           10.0       10            NaN
# 1     A 2024-01-02     12           22.0       22      11.000000
# 2     A 2024-01-03      9           31.0       31      10.333333
# 3     A 2024-01-04     13           44.0       44      11.000000
# 4     B 2024-01-05     20           64.0       64      12.800000
# 5     B 2024-01-06     18           82.0       82      13.666667
# 6     B 2024-01-07     25          107.0      107      15.285714
# 7     B 2024-01-08     22          129.0      129      16.125000

# %%
df["exp_avg_store"] = (
    df.groupby("store")["sales"]
      .expanding(min_periods=1).sum()
      .reset_index(level=0, drop=True)
)
df
# Out:
#   store       date  sales  expanding_sum  cum_sum  exp_mean_min2  \
# 0     A 2024-01-01     10           10.0       10            NaN
# 1     A 2024-01-02     12           22.0       22      11.000000
# 2     A 2024-01-03      9           31.0       31      10.333333
# 3     A 2024-01-04     13           44.0       44      11.000000
# 4     B 2024-01-05     20           64.0       64      12.800000
# 5     B 2024-01-06     18           82.0       82      13.666667
# 6     B 2024-01-07     25          107.0      107      15.285714
# 7     B 2024-01-08     22          129.0      129      16.125000
#
#    exp_avg_store
# 0           10.0
# 1           22.0
# 2           31.0
# 3           44.0
# 4           20.0
# 5           38.0
# 6           63.0
# 7           85.0

# %% [markdown]
# ## ----------- EWM -----------
# > recent rows get more weight
#
# > Provide exponentially weighted (EW) calculations.
#
# > Solution:- Sometimes we want recent data to matter more, older data less → that’s EWM.
#
# > DataFrame.ewm(com=None, span=None, halflife=None, alpha=None, min_periods=0, adjust=True, ignore_na=False, axis=<no_default>, times=None, method='single')

# %% [markdown]
# ##### Formula:- new_avg = alpha * current_value + (1 - alpha) * previous_avg
# where alpha depends on span/halflife.
#
# - Eg: df["ewm_mean"] = df["sales"].ewm(span=3).mean()
# span=3 → controls the “decay rate” (larger span = smoother, slower to react).

# %%
df = pd.DataFrame({
    "store": ["A","A","A","A","B","B","B","B"],
    "date": pd.date_range("2024-01-01", periods=8, freq="D"),
    "sales": [10, 12, 9, 13, 20, 18, 25, 22]
}).sort_values(["store","date"]).reset_index(drop=True)
df
# Out:
#   store       date  sales
# 0     A 2024-01-01     10
# 1     A 2024-01-02     12
# 2     A 2024-01-03      9
# 3     A 2024-01-04     13
# 4     B 2024-01-05     20
# 5     B 2024-01-06     18
# 6     B 2024-01-07     25
# 7     B 2024-01-08     22

# %%
df["ewm_sum"] = df["sales"].ewm(span=3).sum()
df
# Out:
#   store       date  sales    ewm_sum
# 0     A 2024-01-01     10  10.000000
# 1     A 2024-01-02     12  17.000000
# 2     A 2024-01-03      9  17.500000
# 3     A 2024-01-04     13  21.750000
# 4     B 2024-01-05     20  30.875000
# 5     B 2024-01-06     18  33.437500
# 6     B 2024-01-07     25  41.718750
# 7     B 2024-01-08     22  42.859375

# %%
df["ewm_sum_2"] = df["sales"].ewm(alpha=0.5).sum()
df
# Out:
#   store       date  sales    ewm_sum  ewm_sum_2
# 0     A 2024-01-01     10  10.000000  10.000000
# 1     A 2024-01-02     12  17.000000  17.000000
# 2     A 2024-01-03      9  17.500000  17.500000
# 3     A 2024-01-04     13  21.750000  21.750000
# 4     B 2024-01-05     20  30.875000  30.875000
# 5     B 2024-01-06     18  33.437500  33.437500
# 6     B 2024-01-07     25  41.718750  41.718750
# 7     B 2024-01-08     22  42.859375  42.859375

# %% [markdown]
# ##### halflife=2 → value from 2 steps ago has half the weight of the current value.

# %%
df["ewm_sum_half2"] = df["sales"].ewm(halflife=2).sum()
df
# Out:
#   store       date  sales    ewm_sum  ewm_sum_2  ewm_sum_half2
# 0     A 2024-01-01     10  10.000000  10.000000      10.000000
# 1     A 2024-01-02     12  17.000000  17.000000      19.071068
# 2     A 2024-01-03      9  17.500000  17.500000      22.485281
# 3     A 2024-01-04     13  21.750000  21.750000      28.899495
# 4     B 2024-01-05     20  30.875000  30.875000      40.435029
# 5     B 2024-01-06     18  33.437500  33.437500      46.591883
# 6     B 2024-01-07     25  41.718750  41.718750      57.945436
# 7     B 2024-01-08     22  42.859375  42.859375      62.973611

# %% [markdown]
# ##### adjust=True (default) → normalizes weights so they add up to 1.

# %%
df["ewm_adj"] = df["sales"].ewm(span=3, adjust=True).mean()
df
# Out:
#   store       date  sales    ewm_sum  ewm_sum_2  ewm_sum_half2    ewm_adj
# 0     A 2024-01-01     10  10.000000  10.000000      10.000000  10.000000
# 1     A 2024-01-02     12  17.000000  17.000000      19.071068  11.333333
# 2     A 2024-01-03      9  17.500000  17.500000      22.485281  10.000000
# 3     A 2024-01-04     13  21.750000  21.750000      28.899495  11.600000
# 4     B 2024-01-05     20  30.875000  30.875000      40.435029  15.935484
# 5     B 2024-01-06     18  33.437500  33.437500      46.591883  16.984127
# 6     B 2024-01-07     25  41.718750  41.718750      57.945436  21.023622
# 7     B 2024-01-08     22  42.859375  42.859375      62.973611  21.513725

# %%
df["ewm_adj_sum"] = df["sales"].ewm(span=3, adjust=True).sum()
df
# Out:
#   store       date  sales    ewm_sum  ewm_sum_2  ewm_sum_half2    ewm_adj  \
# 0     A 2024-01-01     10  10.000000  10.000000      10.000000  10.000000
# 1     A 2024-01-02     12  17.000000  17.000000      19.071068  11.333333
# 2     A 2024-01-03      9  17.500000  17.500000      22.485281  10.000000
# 3     A 2024-01-04     13  21.750000  21.750000      28.899495  11.600000
# 4     B 2024-01-05     20  30.875000  30.875000      40.435029  15.935484
# 5     B 2024-01-06     18  33.437500  33.437500      46.591883  16.984127
# 6     B 2024-01-07     25  41.718750  41.718750      57.945436  21.023622
# 7     B 2024-01-08     22  42.859375  42.859375      62.973611  21.513725
#
#    ewm_adj_sum
# 0    10.000000
# 1    17.000000
# 2    17.500000
# 3    21.750000
# 4    30.875000
# 5    33.437500
# 6    41.718750
# 7    42.859375

# %% [markdown]
# ##### adjust=False → recursive formula (more common in streaming).

# %%
df["ewm_noadj"] = df["sales"].ewm(span=3, adjust=False).mean()
df
# Out:
#   store       date  sales    ewm_sum  ewm_sum_2  ewm_sum_half2    ewm_adj  \
# 0     A 2024-01-01     10  10.000000  10.000000      10.000000  10.000000
# 1     A 2024-01-02     12  17.000000  17.000000      19.071068  11.333333
# 2     A 2024-01-03      9  17.500000  17.500000      22.485281  10.000000
# 3     A 2024-01-04     13  21.750000  21.750000      28.899495  11.600000
# 4     B 2024-01-05     20  30.875000  30.875000      40.435029  15.935484
# 5     B 2024-01-06     18  33.437500  33.437500      46.591883  16.984127
# 6     B 2024-01-07     25  41.718750  41.718750      57.945436  21.023622
# 7     B 2024-01-08     22  42.859375  42.859375      62.973611  21.513725
#
#    ewm_adj_sum  ewm_noadj
# 0    10.000000   10.00000
# 1    17.000000   11.00000
# 2    17.500000   10.00000
# 3    21.750000   11.50000
# 4    30.875000   15.75000
# 5    33.437500   16.87500
# 6    41.718750   20.93750
# 7    42.859375   21.46875

# %% [markdown]
# ##### ❌❌ NotImplementedError: sum is not implemented with adjust=False ❌❌

# %%
# df["ewm_noadj_sum"] = df["sales"].ewm(span=3, adjust=False).sum()
# df

# %% [markdown]
# ##### with groupby

# %%
df["ewm_store"] = (
    df.groupby("store")["sales"]
      .ewm(span=3, adjust=False).mean()
      .reset_index(level=0, drop=True)
)
df
# Out:
#   store       date  sales    ewm_sum  ewm_sum_2  ewm_sum_half2    ewm_adj  \
# 0     A 2024-01-01     10  10.000000  10.000000      10.000000  10.000000
# 1     A 2024-01-02     12  17.000000  17.000000      19.071068  11.333333
# 2     A 2024-01-03      9  17.500000  17.500000      22.485281  10.000000
# 3     A 2024-01-04     13  21.750000  21.750000      28.899495  11.600000
# 4     B 2024-01-05     20  30.875000  30.875000      40.435029  15.935484
# 5     B 2024-01-06     18  33.437500  33.437500      46.591883  16.984127
# 6     B 2024-01-07     25  41.718750  41.718750      57.945436  21.023622
# 7     B 2024-01-08     22  42.859375  42.859375      62.973611  21.513725
#
#    ewm_adj_sum  ewm_noadj  ewm_store
# 0    10.000000   10.00000       10.0
# 1    17.000000   11.00000       11.0
# 2    17.500000   10.00000       10.0
# 3    21.750000   11.50000       11.5
# 4    30.875000   15.75000       20.0
# 5    33.437500   16.87500       19.0
# 6    41.718750   20.93750       22.0
# 7    42.859375   21.46875       22.0
