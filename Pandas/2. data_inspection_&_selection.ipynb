# %% [markdown]
# # ================= Data Inspection ==================

# %%
import pandas as pd

df = pd.read_csv("analysis-dataset.csv")

data = {
    "Name": ["Alice", "Bob", "Charlie"],
    "Age": [24, 30, 22],
    "City": ["Delhi", "Mumbai", "Bangalore"]
}
df = pd.DataFrame(data)

# %% [markdown]
# ### head()

# %%
df.head(2)
# Out:
#    Order ID        Date    Product  Price  Quantity Purchase Type  \
# 0     10452  07-11-2022      Fries   3.49    573.07       Online
# 1     10453  07-11-2022  Beverages   2.95    745.76       Online
#
#   Payment Method             Manager    City
# 0      Gift Card    Tom      Jackson  London
# 1      Gift Card         Pablo Perez  Madrid

# %% [markdown]
# ### tail()

# %%
df.tail()
# Out:
#      Order ID        Date             Product  Price  Quantity Purchase Type  \
# 249     10709  28-12-2022       Sides & Other   4.99    200.40   Drive-thru
# 250     10710  29-12-2022             Burgers  12.99    754.43   Drive-thru
# 251     10711  29-12-2022  Chicken Sandwiches   9.95    281.41   Drive-thru
# 252     10712  29-12-2022               Fries   3.49    630.37   Drive-thru
# 253     10713  29-12-2022           Beverages   2.95    677.97   Drive-thru
#
#     Payment Method        Manager    City
# 249      Gift Card  Walter Muller  Berlin
# 250      Gift Card  Walter Muller  Berlin
# 251      Gift Card  Walter Muller  Berlin
# 252      Gift Card  Walter Muller  Berlin
# 253      Gift Card  Walter Muller  Berlin

# %%
print(df.shape)
print(df.ndim)
print(df.size)
print(df.axes)    # [row index, column index]
len(df)           # n(rows)
# Out:
# (254, 11)
# 2
# 2794
# [RangeIndex(start=0, stop=254, step=1), Index(['level_0', 'index', 'Date', 'Order ID', 'Product', 'Price', 'Quantity',
#        'Purchase Type', 'Payment Method', 'Manager', 'City'],
#       dtype='object')]
# 254

# %% [markdown]
# ### info()
# > Summary info :::: Info on columns & nulls

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 0 to 253
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   level_0         254 non-null    int64
#  1   index           254 non-null    int64
#  2   Date            254 non-null    object
#  3   Order ID        254 non-null    int64
#  4   Product         254 non-null    object
#  5   Price           254 non-null    float64
#  6   Quantity        254 non-null    float64
#  7   Purchase Type   254 non-null    object
#  8   Payment Method  254 non-null    object
#  9   Manager         254 non-null    object
#  10  City            254 non-null    object
# dtypes: float64(2), int64(3), object(6)
# memory usage: 22.0+ KB

# %% [markdown]
# ### describe()
# > Statistical summary :::: > numerical cols only, unless the parameter: [include="all"] is specified

# %%
df.describe()
# Out:
#          level_0      index      Order ID       Price    Quantity
# count  254.00000  254.00000    254.000000  254.000000  254.000000
# mean   126.50000  126.50000  10584.133858    7.102323  460.611457
# std     73.46768   73.46768     75.889181    4.341855  214.888699
# min      0.00000    0.00000  10452.000000    2.950000  200.400000
# 25%     63.25000   63.25000  10520.250000    3.490000  201.010000
# 50%    126.50000  126.50000  10583.500000    4.990000  538.880000
# 75%    189.75000  189.75000  10649.750000    9.950000  677.440000
# max    253.00000  253.00000  10713.000000   29.050000  754.430000

# %%
pd.DataFrame(df["Order ID"].describe())
# Out:
#            Order ID
# count    254.000000
# mean   10584.133858
# std       75.889181
# min    10452.000000
# 25%    10520.250000
# 50%    10583.500000
# 75%    10649.750000
# max    10713.000000

# %%
pd.DataFrame(df["Product"].describe())
# Out:
#                    Product
# count                  254
# unique                   5
# top     Chicken Sandwiches
# freq                    52

# %%
df.describe(include="all")
# Out:
#           level_0      index        Date      Order ID             Product  \
# count   254.00000  254.00000         254    254.000000                 254
# unique        NaN        NaN          53           NaN                   5
# top           NaN        NaN  09-11-2022           NaN  Chicken Sandwiches
# freq          NaN        NaN           5           NaN                  52
# mean    126.50000  126.50000         NaN  10584.133858                 NaN
# std      73.46768   73.46768         NaN     75.889181                 NaN
# min       0.00000    0.00000         NaN  10452.000000                 NaN
# 25%      63.25000   63.25000         NaN  10520.250000                 NaN
# 50%     126.50000  126.50000         NaN  10583.500000                 NaN
# 75%     189.75000  189.75000         NaN  10649.750000                 NaN
# max     253.00000  253.00000         NaN  10713.000000                 NaN
#
# ...

# %%
print(df["Price"].mean())
print(df["Price"].min())
print(df["Price"].max())
print("-------------------------")
print(df["Price"].unique())            # unique values
print("-------------------------")
print(df["Price"].nunique())           # count of unique values
print("-------------------------")
print(df["Price"].value_counts())      # frequency
# Out:
# 7.102322834645669
# 2.95
# 29.05
# -------------------------
# [ 3.49  2.95  4.99 12.99  9.95 25.5  29.05]
# -------------------------
# 7
# -------------------------
# Price
# 12.99    52
# 9.95     51
# 3.49     50
# 2.95     50
# 4.99     49
# 25.50     1
# 29.05     1
# Name: count, dtype: int64

# %%
print(df["Order ID"].max())
df["Order ID"].max()
# Out:
# 10713
# np.int64(10713)

# %%
df[df['Order ID'] == df['Order ID'].max()]
# Out:
#      level_0  index        Date  Order ID    Product  Price  Quantity  \
# 253      253    253  29-12-2022     10713  Beverages   2.95    677.97
#
#     Purchase Type Payment Method        Manager    City
# 253   Drive-thru       Gift Card  Walter Muller  Berlin

# %%
df[['Order ID', 'Date',	'Product']][df['Order ID'] == df['Order ID'].max()]
# Out:
#      Order ID        Date    Product
# 253     10713  29-12-2022  Beverages

# %% [markdown]
# ❓❓❓❓❓❓❓❓❓❓❓❓❓❓❓❓

# %%
print(df["Product"].min())
print(df["Product"].max())
df["Product"].max()
# Out:
# Beverages
# Sides & Other
# 'Sides & Other'

# %%
df[["Product"]].max()
# Out:
# Product    Sides & Other
# dtype: object

# %%
# df["Product"].top()
#### 'Series' object has no attribute 'top' ####

# %%
# df[["Product"]].top()

# %% [markdown]
# # ================== Data Selection ==================

# %% [markdown]
# ## ----------- COLUMNS -----------

# %%
print("\n============= Fetch particular columns' info ===============")
df['City']
# Out:
# ============= Fetch particular columns' info ===============
# <class 'pandas.core.frame.DataFrame'>
#
# -------------------------
# <class 'pandas.core.series.Series'>
# 0      London
# 1      Madrid
# 2      Lisbon
# 3      Berlin
# 4      Berlin
#         ...
# 249    Berlin
# 250    Berlin
# 251    Berlin
# 252    Berlin
# 253    Berlin
# Name: City, Length: 254, dtype: object

# %%
# df['City', 'Product']
#### KeyError: ('City', 'Product') #####

# %%
df[['City', 'Product']]
# Out:
#        City             Product
# 0    London               Fries
# 1    Madrid           Beverages
# 2    Lisbon       Sides & Other
# 3    Berlin             Burgers
# 4    Berlin  Chicken Sandwiches
# ..      ...                 ...
# 249  Berlin       Sides & Other
# 250  Berlin             Burgers
# 251  Berlin  Chicken Sandwiches
# 252  Berlin               Fries
# 253  Berlin           Beverages
#
# [254 rows x 2 columns]

# %%
# Column by attribute :: {Works only if no space in the col-name}
df.Product
# Out:
# 0                   Fries
# 1               Beverages
# 2           Sides & Other
# 3                 Burgers
# 4      Chicken Sandwiches
#               ...
# 249         Sides & Other
# 250               Burgers
# 251    Chicken Sandwiches
# 252                 Fries
# 253             Beverages
# Name: Product, Length: 254, dtype: object

# %%
# df.'Order ID'
#### SyntaxError: invalid syntax ####

# %%
df['Order ID']
# Out:
# 0      10452
# 1      10453
# 2      10454
# 3      10455
# 4      10456
#        ...
# 249    10709
# 250    10710
# 251    10711
# 252    10712
# 253    10713
# Name: Order ID, Length: 254, dtype: int64

# %% [markdown]
# ## ----------- ROWS -----------

# %% [markdown]
# ### at/ iat

# %%
df
# Out:
#      level_0  index        Date  Order ID             Product  Price  \
# 0          0      0  07-11-2022     10452               Fries   3.49
# 1          1      1  07-11-2022     10453           Beverages   2.95
# 2          2      2  07-11-2022     10454       Sides & Other   4.99
# 3          3      3  08-11-2022     10455             Burgers  12.99
# 4          4      4  08-11-2022     10456  Chicken Sandwiches   9.95
# ..       ...    ...         ...       ...                 ...    ...
# 249      249    249  28-12-2022     10709       Sides & Other   4.99
# 250      250    250  29-12-2022     10710             Burgers  12.99
# 251      251    251  29-12-2022     10711  Chicken Sandwiches   9.95
# 252      252    252  29-12-2022     10712               Fries   3.49
# 253      253    253  29-12-2022     10713           Beverages   2.95
#
#      Quantity Purchase Type Payment Method             Manager    City
# ...

# %%
df.iat[0, 0]  # >> row: 0; col: level_0
# Out:
# np.int64(0)

# %%
df.iat[0, 4]
# Out:
# 'Fries'

# %%
df.at[0, 'Product']
# Out:
# 'Fries'

# %% [markdown]
# ### loc/ iloc

# %%
# By position (iloc)
df.iloc[0:3:2, :]     # first 3 rows (with 1 row skip),  for all columns
# Out:
#    level_0  index        Date  Order ID        Product  Price  Quantity  \
# 0        0      0  07-11-2022     10452          Fries   3.49    573.07
# 2        2      2  07-11-2022     10454  Sides & Other   4.99    200.40
#
#   Purchase Type Payment Method           Manager    City
# 0       Online       Gift Card  Tom      Jackson  London
# 2     In-store       Gift Card     Joao    Silva  Lisbon

# %%
df.iloc[:, :4:2]             # for all rows, first 4 columns (with 1 col skip)
# Out:
#      level_0        Date
# 0          0  07-11-2022
# 1          1  07-11-2022
# 2          2  07-11-2022
# 3          3  08-11-2022
# 4          4  08-11-2022
# ..       ...         ...
# 249      249  28-12-2022
# 250      250  29-12-2022
# 251      251  29-12-2022
# 252      252  29-12-2022
# 253      253  29-12-2022
#
# [254 rows x 2 columns]

# %%
# By label (loc)
df.loc[0:2, ["Product","Price"]] # rows 0→2, specific cols
# Out:
#          Product  Price
# 0          Fries   3.49
# 1      Beverages   2.95
# 2  Sides & Other   4.99

# %% [markdown]
# ### Slicing

# %%
df[1:11:2]
# Out:
#    level_0  index        Date  Order ID    Product  Price  Quantity  \
# 1        1      1  07-11-2022     10453  Beverages   2.95    745.76
# 3        3      3  08-11-2022     10455    Burgers  12.99    569.67
# 5        5      5  08-11-2022     10457      Fries   3.49    573.07
# 7        7      7  09-11-2022     10460    Burgers  12.99    554.27
# 9        9      9  09-11-2022     10462      Fries   3.49    573.07
#
#   Purchase Type Payment Method             Manager    City
# 1       Online       Gift Card         Pablo Perez  Madrid
# 3     In-store     Credit Card       Walter Muller  Berlin
# 5     In-store     Credit Card       Remy    Monet   Paris
# 7     In-store     Credit Card          Remy Monet   Paris
# 9     In-store     Credit Card          Remy Monet   Paris

# %%
df.loc[1:11:2]
# Out:
#     level_0  index        Date  Order ID        Product  Price  Quantity  \
# 1         1      1  07-11-2022     10453      Beverages   2.95    745.76
# 3         3      3  08-11-2022     10455        Burgers  12.99    569.67
# 5         5      5  08-11-2022     10457          Fries   3.49    573.07
# 7         7      7  09-11-2022     10460        Burgers  12.99    554.27
# 9         9      9  09-11-2022     10462          Fries   3.49    573.07
# 11       11     11  09-11-2022     10464  Sides & Other   4.99    200.40
#
#    Purchase Type Payment Method             Manager    City
# 1        Online       Gift Card         Pablo Perez  Madrid
# 3      In-store     Credit Card       Walter Muller  Berlin
# 5      In-store     Credit Card       Remy    Monet   Paris
# 7      In-store     Credit Card          Remy Monet   Paris
# 9      In-store     Credit Card          Remy Monet   Paris
# 11     In-store     Credit Card      Remy     Monet   Paris

# %%
df.iloc[1:11:2]
# Out:
#    level_0  index        Date  Order ID    Product  Price  Quantity  \
# 1        1      1  07-11-2022     10453  Beverages   2.95    745.76
# 3        3      3  08-11-2022     10455    Burgers  12.99    569.67
# 5        5      5  08-11-2022     10457      Fries   3.49    573.07
# 7        7      7  09-11-2022     10460    Burgers  12.99    554.27
# 9        9      9  09-11-2022     10462      Fries   3.49    573.07
#
#   Purchase Type Payment Method             Manager    City
# 1       Online       Gift Card         Pablo Perez  Madrid
# 3     In-store     Credit Card       Walter Muller  Berlin
# 5     In-store     Credit Card       Remy    Monet   Paris
# 7     In-store     Credit Card          Remy Monet   Paris
# 9     In-store     Credit Card          Remy Monet   Paris

# %% [markdown]
# ### sample()

# %%
df.sample()
# Out:
#     level_0  index        Date  Order ID    Product  Price  Quantity  \
# 83       83     83  25-11-2022     10543  Beverages   2.95    745.76
#
#    Purchase Type Payment Method      Manager    City
# 83   Drive-thru     Credit Card  Tom Jackson  London

# %%
df.sample(n=5)
# Out:
#      level_0  index        Date  Order ID        Product  Price  Quantity  \
# 1          1      1  07-11-2022     10453      Beverages   2.95    745.76
# 180      180    180  15-12-2022     10640        Burgers  12.99    538.88
# 60        60     60  13-11-2022     10483      Beverages   2.95    677.97
# 154      154    154  09-12-2022     10614  Sides & Other   4.99    200.40
# 12        12     12  10-11-2022     10465        Burgers  12.99    554.27
#
#     Purchase Type Payment Method             Manager    City
# 1         Online       Gift Card         Pablo Perez  Madrid
# 180       Online       Gift Card          Joao Silva  Lisbon
# 60      In-store     Credit Card       Joao    Silva  Lisbon
# 154       Online       Gift Card         Tom Jackson  London
# 12      In-store     Credit Card         Pablo Perez  Madrid

# %%
df.sample(n=5, random_state=1)
# Out:
#      level_0  index        Date  Order ID             Product  Price  \
# 67        67     67  21-11-2022     10524       Sides & Other   4.99
# 253      253    253  29-12-2022     10713           Beverages   2.95
# 214      214    214  21-12-2022     10674       Sides & Other   4.99
# 244      244    244  27-12-2022     10704       Sides & Other   4.99
# 91        91     91  27-11-2022     10551  Chicken Sandwiches   9.95
#
#      Quantity Purchase Type Payment Method        Manager    City
# 67     200.40   Drive-thru            Cash     Remy Monet   Paris
# 253    677.97   Drive-thru       Gift Card  Walter Muller  Berlin
# 214    200.40     In-store            Cash     Joao Silva  Lisbon
# 244    200.40   Drive-thru       Gift Card  Walter Muller  Berlin
# 91     201.01   Drive-thru     Credit Card    Tom Jackson  London

# %% [markdown]
# ## ----------- BASIC FUNCTIONS -----------

# %% [markdown]
# ### type()

# %%
print(type(df))
print(type(df[["City"]]))
print(type(df['City']))
print(type(df['City'][1]))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>
# <class 'str'>

# %% [markdown]
# ### set_index()

# %%
df.set_index('Date')
# Out:
#             level_0  index  Order ID             Product  Price  Quantity  \
# Date
# 07-11-2022        0      0     10452               Fries   3.49    573.07
# 07-11-2022        1      1     10453           Beverages   2.95    745.76
# 07-11-2022        2      2     10454       Sides & Other   4.99    200.40
# 08-11-2022        3      3     10455             Burgers  12.99    569.67
# 08-11-2022        4      4     10456  Chicken Sandwiches   9.95    201.01
# ...             ...    ...       ...                 ...    ...       ...
# 28-12-2022      249    249     10709       Sides & Other   4.99    200.40
# 29-12-2022      250    250     10710             Burgers  12.99    754.43
# 29-12-2022      251    251     10711  Chicken Sandwiches   9.95    281.41
# 29-12-2022      252    252     10712               Fries   3.49    630.37
# 29-12-2022      253    253     10713           Beverages   2.95    677.97
#
#            Purchase Type Payment Method             Manager
# Date
# ...

# %%
df.set_index('Date').columns
# Out:
# Index(['level_0', 'index', 'Order ID', 'Product', 'Price', 'Quantity',
#        'Purchase Type', 'Payment Method', 'Manager'],
#       dtype='object')

# %%
df.set_index('Date').index
# Out:
# Index(['07-11-2022', '07-11-2022', '07-11-2022', '08-11-2022', '08-11-2022',
#        '08-11-2022', '08-11-2022', '09-11-2022', '09-11-2022', '09-11-2022',
#        ...
#        '27-12-2022', '28-12-2022', '28-12-2022', '28-12-2022', '28-12-2022',
#        '28-12-2022', '29-12-2022', '29-12-2022', '29-12-2022', '29-12-2022'],
#       dtype='object', name='Date', length=254)

# %%
df
# Out:
#      level_0  index        Date  Order ID             Product  Price  \
# 0          0      0  07-11-2022     10452               Fries   3.49
# 1          1      1  07-11-2022     10453           Beverages   2.95
# 2          2      2  07-11-2022     10454       Sides & Other   4.99
# 3          3      3  08-11-2022     10455             Burgers  12.99
# 4          4      4  08-11-2022     10456  Chicken Sandwiches   9.95
# ..       ...    ...         ...       ...                 ...    ...
# 249      249    249  28-12-2022     10709       Sides & Other   4.99
# 250      250    250  29-12-2022     10710             Burgers  12.99
# 251      251    251  29-12-2022     10711  Chicken Sandwiches   9.95
# 252      252    252  29-12-2022     10712               Fries   3.49
# 253      253    253  29-12-2022     10713           Beverages   2.95
#
#      Quantity Purchase Type Payment Method             Manager
# 0      573.07       Online       Gift Card    Tom      Jackson
# ...

# %%
df = pd.read_csv("analysis-dataset.csv")
df.set_index('Date', inplace = True)
df
# Out:
#             Order ID             Product  Price  Quantity Purchase Type  \
# Date
# 07-11-2022     10452               Fries   3.49    573.07       Online
# 07-11-2022     10453           Beverages   2.95    745.76       Online
# 07-11-2022     10454       Sides & Other   4.99    200.40     In-store
# 08-11-2022     10455             Burgers  12.99    569.67     In-store
# 08-11-2022     10456  Chicken Sandwiches   9.95    201.01     In-store
# ...              ...                 ...    ...       ...           ...
# 28-12-2022     10709       Sides & Other   4.99    200.40   Drive-thru
# 29-12-2022     10710             Burgers  12.99    754.43   Drive-thru
# 29-12-2022     10711  Chicken Sandwiches   9.95    281.41   Drive-thru
# 29-12-2022     10712               Fries   3.49    630.37   Drive-thru
# 29-12-2022     10713           Beverages   2.95    677.97   Drive-thru
#
#            Payment Method             Manager    City
# Date
# ...

# %% [markdown]
# ### reset_index()
# > Can go uptil 3 levels => date -> index -> level_0

# %%
df.reset_index(inplace = True)
print(df.columns)
df
# Out:
# Index(['Date', 'Order ID', 'Product', 'Price', 'Quantity', 'Purchase Type',
#        'Payment Method', 'Manager', 'City'],
#       dtype='object')
#            Date  Order ID             Product  Price  Quantity Purchase Type  \
# 0    07-11-2022     10452               Fries   3.49    573.07       Online
# 1    07-11-2022     10453           Beverages   2.95    745.76       Online
# 2    07-11-2022     10454       Sides & Other   4.99    200.40     In-store
# 3    08-11-2022     10455             Burgers  12.99    569.67     In-store
# 4    08-11-2022     10456  Chicken Sandwiches   9.95    201.01     In-store
# ..          ...       ...                 ...    ...       ...           ...
# 249  28-12-2022     10709       Sides & Other   4.99    200.40   Drive-thru
# 250  29-12-2022     10710             Burgers  12.99    754.43   Drive-thru
# 251  29-12-2022     10711  Chicken Sandwiches   9.95    281.41   Drive-thru
# ...

# %%
df.reset_index(inplace = True)
print(df.columns)
df
# Out:
# Index(['index', 'Date', 'Order ID', 'Product', 'Price', 'Quantity',
#        'Purchase Type', 'Payment Method', 'Manager', 'City'],
#       dtype='object')
#      index        Date  Order ID             Product  Price  Quantity  \
# 0        0  07-11-2022     10452               Fries   3.49    573.07
# 1        1  07-11-2022     10453           Beverages   2.95    745.76
# 2        2  07-11-2022     10454       Sides & Other   4.99    200.40
# 3        3  08-11-2022     10455             Burgers  12.99    569.67
# 4        4  08-11-2022     10456  Chicken Sandwiches   9.95    201.01
# ..     ...         ...       ...                 ...    ...       ...
# 249    249  28-12-2022     10709       Sides & Other   4.99    200.40
# 250    250  29-12-2022     10710             Burgers  12.99    754.43
# 251    251  29-12-2022     10711  Chicken Sandwiches   9.95    281.41
# 252    252  29-12-2022     10712               Fries   3.49    630.37
# ...

# %%
df.reset_index(inplace = True)
print(df.columns)
df
# Out:
# Index(['level_0', 'index', 'Date', 'Order ID', 'Product', 'Price', 'Quantity',
#        'Purchase Type', 'Payment Method', 'Manager', 'City'],
#       dtype='object')
#      level_0  index        Date  Order ID             Product  Price  \
# 0          0      0  07-11-2022     10452               Fries   3.49
# 1          1      1  07-11-2022     10453           Beverages   2.95
# 2          2      2  07-11-2022     10454       Sides & Other   4.99
# 3          3      3  08-11-2022     10455             Burgers  12.99
# 4          4      4  08-11-2022     10456  Chicken Sandwiches   9.95
# ..       ...    ...         ...       ...                 ...    ...
# 249      249    249  28-12-2022     10709       Sides & Other   4.99
# 250      250    250  29-12-2022     10710             Burgers  12.99
# 251      251    251  29-12-2022     10711  Chicken Sandwiches   9.95
# 252      252    252  29-12-2022     10712               Fries   3.49
# ...

# %%
# df.reset_index(inplace = True)
print(df.columns)
df
# Out:
# Index(['level_0', 'index', 'Date', 'Order ID', 'Product', 'Price', 'Quantity',
#        'Purchase Type', 'Payment Method', 'Manager', 'City'],
#       dtype='object')
#      level_0  index        Date  Order ID             Product  Price  \
# 0          0      0  07-11-2022     10452               Fries   3.49
# 1          1      1  07-11-2022     10453           Beverages   2.95
# 2          2      2  07-11-2022     10454       Sides & Other   4.99
# 3          3      3  08-11-2022     10455             Burgers  12.99
# 4          4      4  08-11-2022     10456  Chicken Sandwiches   9.95
# ..       ...    ...         ...       ...                 ...    ...
# 249      249    249  28-12-2022     10709       Sides & Other   4.99
# 250      250    250  29-12-2022     10710             Burgers  12.99
# 251      251    251  29-12-2022     10711  Chicken Sandwiches   9.95
# 252      252    252  29-12-2022     10712               Fries   3.49
# ...

# %% [markdown]
# ## ----------- Filtering -----------

# %% [markdown]
# ### isin()

# %%
df[df["City"].isin(["Berlin", "Chennai"])]
# Out:
#      level_0  index        Date  Order ID             Product  Price  \
# 3          3      3  08-11-2022     10455             Burgers  12.99
# 4          4      4  08-11-2022     10456  Chicken Sandwiches   9.95
# 6          6      6  08-11-2022     10459       Sides & Other   4.99
# 227      227    227  24-12-2022     10687               Fries   3.49
# 228      228    228  24-12-2022     10688           Beverages   2.95
# 229      229    229  24-12-2022     10689       Sides & Other   4.99
# 230      230    230  25-12-2022     10690             Burgers  12.99
# 231      231    231  25-12-2022     10691  Chicken Sandwiches   9.95
# 232      232    232  25-12-2022     10692               Fries   3.49
# 233      233    233  25-12-2022     10693           Beverages   2.95
# 234      234    234  25-12-2022     10694       Sides & Other   4.99
# 235      235    235  26-12-2022     10695             Burgers  12.99
# 236      236    236  26-12-2022     10696  Chicken Sandwiches   9.95
# ...

# %%
df[~df["City"].isin(["Berlin"])]   # not in
# Out:
#      level_0  index        Date  Order ID             Product  Price  \
# 0          0      0  07-11-2022     10452               Fries   3.49
# 1          1      1  07-11-2022     10453           Beverages   2.95
# 2          2      2  07-11-2022     10454       Sides & Other   4.99
# 5          5      5  08-11-2022     10457               Fries   3.49
# 7          7      7  09-11-2022     10460             Burgers  12.99
# ..       ...    ...         ...       ...                 ...    ...
# 222      222    222  23-12-2022     10682               Fries   3.49
# 223      223    223  23-12-2022     10683           Beverages   2.95
# 224      224    224  23-12-2022     10684       Sides & Other   4.99
# 225      225    225  24-12-2022     10685             Burgers  12.99
# 226      226    226  24-12-2022     10686  Chicken Sandwiches   9.95
#
#      Quantity Purchase Type Payment Method             Manager    City
# ...

# %% [markdown]
# ### str Methods

# %%
# String filter
df[df["City"].str.contains("Lon")]
# Out:
#      level_0  index        Date  Order ID             Product  Price  \
# 0          0      0  07-11-2022     10452               Fries   3.49
# 81        81     81  25-11-2022     10541  Chicken Sandwiches   9.95
# 82        82     82  25-11-2022     10542               Fries   3.49
# 83        83     83  25-11-2022     10543           Beverages   2.95
# 84        84     84  25-11-2022     10544       Sides & Other   4.99
# ..       ...    ...         ...       ...                 ...    ...
# 163      163    163  11-12-2022     10623           Beverages   2.95
# 164      164    164  11-12-2022     10624       Sides & Other   4.99
# 165      165    165  12-12-2022     10625             Burgers  12.99
# 166      166    166  12-12-2022     10626  Chicken Sandwiches   9.95
# 167      167    167  12-12-2022     10627               Fries   3.49
#
#      Quantity Purchase Type Payment Method           Manager    City
# 0      573.07       Online       Gift Card  Tom      Jackson  London
# ...

# %%
df["Product"].str.lower()
# Out:
# 0                   fries
# 1               beverages
# 2           sides & other
# 3                 burgers
# 4      chicken sandwiches
#               ...
# 249         sides & other
# 250               burgers
# 251    chicken sandwiches
# 252                 fries
# 253             beverages
# Name: Product, Length: 254, dtype: object

# %% [markdown]
# ### Conditions

# %%
# Rows where condition is True
print(type(df['Order ID'] < 10455))

print("------------")
print(df['Order ID'] < 10455)

print("\n------------")
df[df['Order ID'] < 10455]
# Out:
# <class 'pandas.core.series.Series'>
# ------------
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 249    False
# 250    False
# 251    False
# 252    False
# 253    False
# Name: Order ID, Length: 254, dtype: bool
#
# ------------
#    level_0  index        Date  Order ID        Product  Price  Quantity  \
# 0        0      0  07-11-2022     10452          Fries   3.49    573.07
# 1        1      1  07-11-2022     10453      Beverages   2.95    745.76
# 2        2      2  07-11-2022     10454  Sides & Other   4.99    200.40
#
#   Purchase Type Payment Method             Manager    City
# 0       Online       Gift Card    Tom      Jackson  London
# 1       Online       Gift Card         Pablo Perez  Madrid
# 2     In-store       Gift Card       Joao    Silva  Lisbon

# %%
df
# Out:
#      level_0  index        Date  Order ID             Product  Price  \
# 0          0      0  07-11-2022     10452               Fries   3.49
# 1          1      1  07-11-2022     10453           Beverages   2.95
# 2          2      2  07-11-2022     10454       Sides & Other   4.99
# 3          3      3  08-11-2022     10455             Burgers  12.99
# 4          4      4  08-11-2022     10456  Chicken Sandwiches   9.95
# ..       ...    ...         ...       ...                 ...    ...
# 249      249    249  28-12-2022     10709       Sides & Other   4.99
# 250      250    250  29-12-2022     10710             Burgers  12.99
# 251      251    251  29-12-2022     10711  Chicken Sandwiches   9.95
# 252      252    252  29-12-2022     10712               Fries   3.49
# 253      253    253  29-12-2022     10713           Beverages   2.95
#
#      Quantity Purchase Type Payment Method             Manager    City
# ...

# %%
# Multiple conditions (use & , | , !)
df[
    (df['Order ID'] % 2 == 0) 
    & ((df["City"] == "London") | (df["City"] == "Berlin"))
    & (df["Purchase Type"] != "Online")  # ❓❓ Not Working
    ]
# Out:
#      level_0  index        Date  Order ID             Product  Price  \
# 0          0      0  07-11-2022     10452               Fries   3.49
# 4          4      4  08-11-2022     10456  Chicken Sandwiches   9.95
# 82        82     82  25-11-2022     10542               Fries   3.49
# 84        84     84  25-11-2022     10544       Sides & Other   4.99
# 86        86     86  26-11-2022     10546  Chicken Sandwiches   9.95
# 88        88     88  26-11-2022     10548           Beverages   2.95
# 90        90     90  27-11-2022     10550             Burgers  12.99
# 92        92     92  27-11-2022     10552               Fries   3.49
# 94        94     94  27-11-2022     10554       Sides & Other   4.99
# 96        96     96  28-11-2022     10556  Chicken Sandwiches   9.95
# 98        98     98  28-11-2022     10558           Beverages   2.95
# 100      100    100  29-11-2022     10560             Burgers  12.99
# 102      102    102  29-11-2022     10562               Fries   3.49
# ...

# %% [markdown]
# ### Query
# > Query the columns of a DataFrame with a boolean expression.

# %%
df.iloc[0:3, 0:5].query
# Out:
# <bound method DataFrame.query of    level_0  index        Date  Order ID        Product
# 0        0      0  07-11-2022     10452          Fries
# 1        1      1  07-11-2022     10453      Beverages
# 2        2      2  07-11-2022     10454  Sides & Other>

# %%
# df.iloc[:10, :5].query("City == 'Berlin'")         # ❌ UndefinedVariableError: name 'City' is not defined

# %%
df.iloc[:230].query("City == 'Berlin'")
# Out:
#      level_0  index        Date  Order ID             Product  Price  \
# 3          3      3  08-11-2022     10455             Burgers  12.99
# 4          4      4  08-11-2022     10456  Chicken Sandwiches   9.95
# 6          6      6  08-11-2022     10459       Sides & Other   4.99
# 227      227    227  24-12-2022     10687               Fries   3.49
# 228      228    228  24-12-2022     10688           Beverages   2.95
# 229      229    229  24-12-2022     10689       Sides & Other   4.99
#
#      Quantity Purchase Type Payment Method        Manager    City
# 3      569.67     In-store     Credit Card  Walter Muller  Berlin
# 4      201.01     In-store     Credit Card  Walter Muller  Berlin
# 6      200.40     In-store     Credit Card  Walter Muller  Berlin
# 227    630.37     In-store            Cash  Walter Muller  Berlin
# 228    677.97     In-store            Cash  Walter Muller  Berlin
# 229    200.40     In-store            Cash  Walter Muller  Berlin

# %%
df.iloc[:230].query("City == 'Berlin' and Product == 'Sides & Other'")
# Out:
#      level_0  index        Date  Order ID        Product  Price  Quantity  \
# 6          6      6  08-11-2022     10459  Sides & Other   4.99     200.4
# 229      229    229  24-12-2022     10689  Sides & Other   4.99     200.4
#
#     Purchase Type Payment Method        Manager    City
# 6       In-store     Credit Card  Walter Muller  Berlin
# 229     In-store            Cash  Walter Muller  Berlin
