# %% [markdown]
# # ================ Data Cleaning ================

# %%
import pandas as pd

# %% [markdown]
# ## ----------- Handling Missing Data -----------
# > Missing values often appear as NaN (Not a Number).

# %%
df = pd.read_csv("weather_data.csv")
df
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017          NaN        9.0   Sunny
# 2   1/5/2017         28.0        NaN    Snow
# 3   1/6/2017          NaN        7.0     NaN
# 4   1/7/2017         32.0        NaN    Rain
# 5   1/8/2017          NaN        NaN   Sunny
# 6   1/9/2017          NaN        NaN     NaN
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %% [markdown]
# #### Ensure date date-type

# %%
print(type(df.day[0]))
df = pd.read_csv("weather_data.csv",parse_dates=['day'])
print(type(df.day[0]))
df
# Out:
# <class 'float'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# /tmp/ipykernel_719000/1011780238.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(type(df.day[0]))
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        9.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08          NaN        NaN   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %% [markdown]
# #### Use date col as index

# %%
df.set_index('day',inplace=True)
df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %% [markdown]
# ### ---------- Check for missing values ----------

# %%
print(df.isnull())          # Shows True/False for missing values
print("\n----------------------")
print(df.isnull().sum())    # Count missing values per column
print("\n----------------------")
df.notnull()                # Opposite of isnull()
# Out:
#             temperature  windspeed  event
# day
# 2017-01-01        False      False  False
# 2017-01-04         True      False  False
# 2017-01-05        False       True  False
# 2017-01-06         True      False   True
# 2017-01-07        False       True  False
# 2017-01-08         True       True  False
# 2017-01-09         True       True   True
# 2017-01-10        False      False  False
# 2017-01-11        False      False  False
#
# ----------------------
# temperature    4
# windspeed      4
# event          2
# dtype: int64
#
# ----------------------
#             temperature  windspeed  event
# day
# 2017-01-01         True       True   True
# 2017-01-04        False       True   True
# 2017-01-05         True      False   True
# 2017-01-06        False       True  False
# 2017-01-07         True      False   True
# 2017-01-08        False      False   True
# 2017-01-09        False      False  False
# 2017-01-10         True       True   True
# 2017-01-11         True       True   True

# %%
print(df.isna())          # Shows True/False for missing values
print("\n----------------------")
print(df.isna().sum())    # Count missing values per column
print("\n----------------------")
df.notna()                # Opposite of isnull()
# Out:
#             temperature  windspeed  event
# 2017-01-01        False      False  False
# 2017-01-02         True       True   True
# 2017-01-03         True       True   True
# 2017-01-04         True      False  False
# 2017-01-05        False       True  False
# 2017-01-06         True      False   True
# 2017-01-07        False       True  False
# 2017-01-08         True       True  False
# 2017-01-09         True       True   True
# 2017-01-10        False      False  False
# 2017-01-11        False      False  False
#
# ----------------------
# temperature    6
# windspeed      6
# event          4
# dtype: int64
#
# ----------------------
#             temperature  windspeed  event
# 2017-01-01         True       True   True
# 2017-01-02        False      False  False
# 2017-01-03        False      False  False
# 2017-01-04        False       True   True
# 2017-01-05         True      False   True
# 2017-01-06        False       True  False
# 2017-01-07         True      False   True
# 2017-01-08        False      False   True
# 2017-01-09        False      False  False
# 2017-01-10         True       True   True
# 2017-01-11         True       True   True

# %% [markdown]
# ### ---------- Drop missing values ----------
# > DataFrame.dropna(*, axis=0/"rows", how='any', thresh=<no_default>, subset=None, inplace=False, ignore_index=False)

# %%
df.dropna()                # Drop rows with ANY missing values
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
df.dropna(axis=1)      # Determine which axis to remove
# Out:
#          day
# 0   1/1/2017
# 1   1/4/2017
# 2   1/5/2017
# 3   1/6/2017
# 4   1/7/2017
# 5   1/8/2017
# 6   1/9/2017
# 7  1/10/2017
# 8  1/11/2017

# %%
df.dropna(axis="columns")
# Out:
#          day
# 0   1/1/2017
# 1   1/4/2017
# 2   1/5/2017
# 3   1/6/2017
# 4   1/7/2017
# 5   1/8/2017
# 6   1/9/2017
# 7  1/10/2017
# 8  1/11/2017

# %%
df.dropna(how='all')       # Drop rows only if ALL values are missing
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017          NaN        9.0   Sunny
# 2   1/5/2017         28.0        NaN    Snow
# 3   1/6/2017          NaN        7.0     NaN
# 4   1/7/2017         32.0        NaN    Rain
# 5   1/8/2017          NaN        NaN   Sunny
# 6   1/9/2017          NaN        NaN     NaN
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %%
df.dropna(subset=['event', 'temperature']) # Drop rows only if val missing in the certain col
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 2   1/5/2017         28.0        NaN    Snow
# 4   1/7/2017         32.0        NaN    Rain
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %%
# ❗❗ Cannot be combind with 'how'❗❗
df.dropna(thresh=2) # Among consecutive NaNs, drop only n(rows) = threshold value only
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017          NaN        9.0   Sunny
# 2   1/5/2017         28.0        NaN    Snow
# 3   1/6/2017          NaN        7.0     NaN
# 4   1/7/2017         32.0        NaN    Rain
# 5   1/8/2017          NaN        NaN   Sunny
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %% [markdown]
# ### Fill missing values

# %% [markdown]
# #### ------ fillna() ------
# > DataFrame.fillna(value=None, *, method=None, axis=None, inplace=False, limit=None, downcast=<no_default>)

# %%
# Filling '0' in place of on all occurances of NaN
df.fillna(0)
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017          0.0        9.0   Sunny
# 2   1/5/2017         28.0        0.0    Snow
# 3   1/6/2017          0.0        7.0       0
# 4   1/7/2017         32.0        0.0    Rain
# 5   1/8/2017          0.0        0.0   Sunny
# 6   1/9/2017          0.0        0.0       0
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %%
df.fillna(0, limit=2)
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017          0.0        9.0   Sunny
# 2   1/5/2017         28.0        0.0    Snow
# 3   1/6/2017          0.0        7.0       0
# 4   1/7/2017         32.0        0.0    Rain
# 5   1/8/2017          NaN        NaN   Sunny
# 6   1/9/2017          NaN        NaN       0
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %%
# ❓❓ Why not 0.0 this tie ❓❓
df.fillna(0, axis=1)
# Out:
#          day temperature windspeed   event
# 0   1/1/2017        32.0       6.0    Rain
# 1   1/4/2017           0       9.0   Sunny
# 2   1/5/2017        28.0         0    Snow
# 3   1/6/2017           0       7.0       0
# 4   1/7/2017        32.0         0    Rain
# 5   1/8/2017           0         0   Sunny
# 6   1/9/2017           0         0       0
# 7  1/10/2017        34.0       8.0  Cloudy
# 8  1/11/2017        40.0      12.0   Sunny

# %%
df.fillna(0, axis=1, limit=1)
# Out:
#          day temperature windspeed   event
# 0   1/1/2017        32.0       6.0    Rain
# 1   1/4/2017           0       9.0   Sunny
# 2   1/5/2017        28.0         0    Snow
# 3   1/6/2017           0       7.0     NaN
# 4   1/7/2017        32.0         0    Rain
# 5   1/8/2017           0       NaN   Sunny
# 6   1/9/2017           0       NaN     NaN
# 7  1/10/2017        34.0       8.0  Cloudy
# 8  1/11/2017        40.0      12.0   Sunny

# %%
df.fillna(0, axis=1, limit=2)
# Out:
#          day temperature windspeed   event
# 0   1/1/2017        32.0       6.0    Rain
# 1   1/4/2017           0       9.0   Sunny
# 2   1/5/2017        28.0         0    Snow
# 3   1/6/2017           0       7.0       0
# 4   1/7/2017        32.0         0    Rain
# 5   1/8/2017           0         0   Sunny
# 6   1/9/2017           0         0     NaN
# 7  1/10/2017        34.0       8.0  Cloudy
# 8  1/11/2017        40.0      12.0   Sunny

# %% [markdown]
# #### > Fill NaN values with specific values for particular columns

# %%
new_df = df.fillna({
        'temperature': 0,
        'windspeed': 0,
        'event': 'No Event'
    })
new_df
# Out:
#             temperature  windspeed     event
# day
# 2017-01-01         32.0        6.0      Rain
# 2017-01-04          0.0        9.0     Sunny
# 2017-01-05         28.0        0.0      Snow
# 2017-01-06          0.0        7.0  No Event
# 2017-01-07         32.0        0.0      Rain
# 2017-01-08          0.0        0.0     Sunny
# 2017-01-09          0.0        0.0  No Event
# 2017-01-10         34.0        8.0    Cloudy
# 2017-01-11         40.0       12.0     Sunny

# %% [markdown]
# #### > Filling NaNs with values comparitive to other cells instead of fixed values

# %%
# df['temperature'].fillna(df['temperature'].mean(), inplace=True)   # ❗❗NOT THE PREFERRED WAY❗❗
df.fillna({'temperature': df['temperature'].mean()}, inplace=True)   # Fill with mean
df
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017         33.2        9.0   Sunny
# 2   1/5/2017         28.0        NaN    Snow
# 3   1/6/2017         33.2        7.0     NaN
# 4   1/7/2017         32.0        NaN    Rain
# 5   1/8/2017         33.2        NaN   Sunny
# 6   1/9/2017         33.2        NaN     NaN
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %% [markdown]
# ##### method & axis

# %%
new_df = df.fillna(method="ffill")   # fill in 'top-to-bottom' manner
# OR
# new_df = df.fillna(method="ffill", axis="index")   # fill in 'top-to-bottom' manner
# OR
# new_df = df.fillna(method="bfill")   # fill in 'bottom-to-top' manner
# OR
# new_df = df.fillna(method="ffill", axis=1)   # fill in 'left-to-right' manner
# OR
# new_df = df.fillna(method="bfill", axis=1)   # fill in 'right-to-left' manner
# OR
# new_df = df.fillna(method="bfill", axis="columns")   # fill in 'right-to-left' manner
new_df
# Out:
# /tmp/ipykernel_719000/446200605.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   new_df = df.fillna(method="ffill")   # fill in 'top-to-bottom' manner
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         33.2        9.0   Sunny
# 2017-01-05         28.0        9.0    Snow
# 2017-01-06         33.2        7.0    Snow
# 2017-01-07         32.0        7.0    Rain
# 2017-01-08         33.2        7.0   Sunny
# 2017-01-09         33.2        7.0   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %% [markdown]
# ##### limit

# %%
new_df = df.fillna(method="ffill",limit=1)
new_df
# Out:
# /tmp/ipykernel_719000/2057544078.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   new_df = df.fillna(method="ffill",limit=1)
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         33.2        9.0   Sunny
# 2017-01-05         28.0        9.0    Snow
# 2017-01-06         33.2        7.0    Snow
# 2017-01-07         32.0        7.0    Rain
# 2017-01-08         33.2        NaN   Sunny
# 2017-01-09         33.2        NaN   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %% [markdown]
# #### Non-deprecating methods

# %%
df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         33.2        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06         33.2        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08         33.2        NaN   Sunny
# 2017-01-09         33.2        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
df.ffill()
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         33.2        9.0   Sunny
# 2017-01-05         28.0        9.0    Snow
# 2017-01-06         33.2        7.0    Snow
# 2017-01-07         32.0        7.0    Rain
# 2017-01-08         33.2        7.0   Sunny
# 2017-01-09         33.2        7.0   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
df.bfill()
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         33.2        9.0   Sunny
# 2017-01-05         28.0        7.0    Snow
# 2017-01-06         33.2        7.0    Rain
# 2017-01-07         32.0        8.0    Rain
# 2017-01-08         33.2        8.0   Sunny
# 2017-01-09         33.2        8.0  Cloudy
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
df.ffill(limit=1)
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         33.2        9.0   Sunny
# 2017-01-05         28.0        9.0    Snow
# 2017-01-06         33.2        7.0    Snow
# 2017-01-07         32.0        7.0    Rain
# 2017-01-08         33.2        NaN   Sunny
# 2017-01-09         33.2        NaN   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
df.ffill(limit=1, axis=1)
# Out:
#          day temperature windspeed   event
# 0   1/1/2017        32.0       6.0    Rain
# 1   1/4/2017        33.2       9.0   Sunny
# 2   1/5/2017        28.0      28.0    Snow
# 3   1/6/2017        33.2       7.0     7.0
# 4   1/7/2017        32.0      32.0    Rain
# 5   1/8/2017        33.2      33.2   Sunny
# 6   1/9/2017        33.2      33.2     NaN
# 7  1/10/2017        34.0       8.0  Cloudy
# 8  1/11/2017        40.0      12.0   Sunny

# %% [markdown]
# ### ------ interpolate() ------
# > DataFrame.interpolate(method='linear', *, axis=0, limit=None, inplace=False, limit_direction=None, limit_area=None, downcast=<no_default>, **kwargs)

# %%
# ❗❗FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.❗❗
new_df = df.interpolate()
new_df
# Out:
# /tmp/ipykernel_719000/3090188840.py:2: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   new_df = df.interpolate()
#            temperature  windspeed   event
# day
# 1/1/2017          32.0       6.00    Rain
# 1/4/2017          33.2       9.00   Sunny
# 1/5/2017          28.0       8.00    Snow
# 1/6/2017          33.2       7.00     NaN
# 1/7/2017          32.0       7.25    Rain
# 1/8/2017          33.2       7.50   Sunny
# 1/9/2017          33.2       7.75     NaN
# 1/10/2017         34.0       8.00  Cloudy
# 1/11/2017         40.0      12.00   Sunny

# %%
df
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017          33.2        9.0   Sunny
# 1/5/2017          28.0        NaN    Snow
# 1/6/2017          33.2        7.0     NaN
# 1/7/2017          32.0        NaN    Rain
# 1/8/2017          33.2        NaN   Sunny
# 1/9/2017          33.2        NaN     NaN
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
new_df = df.interpolate(method="time") 
new_df
# Out:
# /tmp/ipykernel_719000/2760325171.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   new_df = df.interpolate(method="time")
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[369], line 1
# ----> 1 new_df = df.interpolate(method="time")
#       2 new_df
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:8499, in NDFrame.interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    8497 else:
#    8498     index = missing.get_interp_index(method, obj.index)
# -> 8499     new_data = obj._mgr.interpolate(
#    8500         method=method,
#    8501         index=index,
#    8502         limit=limit,
#    8503         limit_direction=limit_direction,
#    8504         limit_area=limit_area,
#    8505         inplace=inplace,
#    8506         downcast=downcast,
#    8507         **kwargs,
#    8508     )
#    8510 result = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    8511 if should_transpose:
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/base.py:291, in DataManager.interpolate(self, inplace, **kwargs)
#     290 def interpolate(self, inplace: bool, **kwargs) -> Self:
# --> 291     return self.apply_with_block(
#     292         "interpolate",
#     293         inplace=inplace,
#     294         **kwargs,
#     295         using_cow=using_copy_on_write(),
#     296         already_warned=_AlreadyWarned(),
#     297     )
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/blocks.py:1797, in Block.interpolate(self, method, index, inplace, limit, limit_direction, limit_area, downcast, using_cow, already_warned, **kwargs)
#    1794 copy, refs = self._get_refs_and_copy(using_cow, inplace)
#    1796 # Dispatch to the EA method.
# -> 1797 new_values = self.array_values.interpolate(
#    1798     method=method,
#    1799     axis=self.ndim - 1,
#    1800     index=index,
#    1801     limit=limit,
#    1802     limit_direction=limit_direction,
#    1803     limit_area=limit_area,
#    1804     copy=copy,
#    1805     **kwargs,
#    1806 )
#    1807 data = extract_array(new_values, extract_numpy=True)
#    1809 if (
#    1810     not copy
#    1811     and warn_copy_on_write()
#    1812     and already_warned is not None
#    1813     and not already_warned.warned_already
#    1814 ):
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/arrays/numpy_.py:296, in NumpyExtensionArray.interpolate(self, method, axis, index, limit, limit_direction, limit_area, copy, **kwargs)
#     293     out_data = self._ndarray.copy()
#     295 # TODO: assert we have floating dtype?
# --> 296 missing.interpolate_2d_inplace(
#     297     out_data,
#     298     method=method,
#     299     axis=axis,
#     300     index=index,
#     301     limit=limit,
#     302     limit_direction=limit_direction,
#     303     limit_area=limit_area,
#     304     **kwargs,
#     305 )
#     306 if not copy:
#     307     return self
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/missing.py:373, in interpolate_2d_inplace(data, index, axis, method, limit, limit_direction, limit_area, fill_value, mask, **kwargs)
#     371 if method == "time":
#     372     if not needs_i8_conversion(index.dtype):
# --> 373         raise ValueError(
#     374             "time-weighted interpolation only works "
#     375             "on Series or DataFrames with a "
#     376             "DatetimeIndex"
#     377         )
#     378     method = "values"
#     380 limit_direction = validate_limit_direction(limit_direction)
#
# ValueError: time-weighted interpolation only works on Series or DataFrames with a DatetimeIndex

# %%
new_df = df.interpolate(method="quadratic") 
new_df
# Out:
# /tmp/ipykernel_719000/2308263592.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   new_df = df.interpolate(method="quadratic")
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[366], line 1
# ----> 1 new_df = df.interpolate(method="quadratic")
#       2 new_df
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:8498, in NDFrame.interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    8489     new_data = obj._mgr.pad_or_backfill(
#    8490         method=method,
#    8491         axis=self._get_block_manager_axis(axis),
#    (...)
#    8495         downcast=downcast,
#    8496     )
#    8497 else:
# -> 8498     index = missing.get_interp_index(method, obj.index)
#    8499     new_data = obj._mgr.interpolate(
#    8500         method=method,
#    8501         index=index,
#    (...)
#    8507         **kwargs,
#    8508     )
#    8510 result = self._constructor_from_mgr(new_data, axes=new_data.axes)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/missing.py:327, in get_interp_index(method, index)
#     321     is_numeric_or_datetime = (
#     322         is_numeric_dtype(index.dtype)
#     323         or isinstance(index.dtype, DatetimeTZDtype)
#     324         or lib.is_np_dtype(index.dtype, "mM")
#     325     )
#     326     if method not in methods and not is_numeric_or_datetime:
# --> 327         raise ValueError(
#     328             "Index column must be numeric or datetime type when "
#     329             f"using {method} method other than linear. "
#     330             "Try setting a numeric or datetime index column before "
#     331             "interpolating."
#     332         )
#     334 if isna(index).any():
#     335     raise NotImplementedError(
#     336         "Interpolation with NaNs in the index "
#     337         "has not been implemented. Try filling "
#     338         "those NaNs before interpolating."
#     339     )
#
# ValueError: Index column must be numeric or datetime type when using quadratic method other than linear. Try setting a numeric or datetime index column before interpolating.

# %% [markdown]
# ### ------ Inserting Missing Rows for Continuity in Dates ------

# %%
df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
dt = pd.date_range("01-01-2017","01-11-2017")
idx = pd.DatetimeIndex(dt)
df = df.reindex(idx)
df
# Out:
#             temperature  windspeed   event
# 2017-01-01         32.0        6.0    Rain
# 2017-01-02          NaN        NaN     NaN
# 2017-01-03          NaN        NaN     NaN
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %% [markdown]
# ## 2. Handling Duplicates
# > When datasets have repeated rows

# %%
df2 = pd.DataFrame({
    'ID': [1,2,2,3,4,4],
    'Name': ['A','B','B','C','D','D']
})
df2
# Out:
#    ID Name
# 0   1    A
# 1   2    B
# 2   2    B
# 3   3    C
# 4   4    D
# 5   4    D

# %% [markdown]
# ### Find duplicates

# %% [markdown]
# ##### count()
# > .count() counts non-null values in each column
#
# > Hence must specify col-name
#
# > .count() ignores NaN values

# %%
df2.count()   # Count duplicates
# Out:
# ID      6
# Name    6
# dtype: int64

# %%
df2.groupby('Name').count()
# Out:
#       ID
# Name
# A      1
# B      2
# C      1
# D      2

# %% [markdown]
# ##### value_counts()
# > This one just counts how often each unique value appears in a column.

# %%
df2['Name'].value_counts()
# Out:
# Name
# B    2
# D    2
# A    1
# C    1
# Name: count, dtype: int64

# %% [markdown]
# ##### duplicated()

# %%
df2.duplicated()         # Returns True if answer for the question is yes:- Have I seen this value before?
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5     True
# dtype: bool

# %%
dupes = df2.duplicated(keep=False)         # it marks all duplicates as True
dupes
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# 4     True
# 5     True
# dtype: bool

# %%
dupes = df2[df2.duplicated("email", keep=False)]
dupes
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_185899/2654170371.py in ?()
# ----> 1 dupes = df2[df2.duplicated("email", keep=False)]
#       2 dupes
#
# ~/.local/lib/python3.10/site-packages/pandas/core/frame.py in ?(self, subset, keep)
#    6946         # Otherwise, raise a KeyError, same as if you try to __getitem__ with a
#    6947         # key that doesn't exist.
#    6948         diff = set(subset) - set(self.columns)
#    6949         if diff:
# -> 6950             raise KeyError(Index(diff))
#    6951
#    6952         if len(subset) == 1 and self.columns.is_unique:
#    6953             # GH#45236 This is faster than get_group_index below
#
# KeyError: Index(['email'], dtype='object')

# %%
dupes[["email"]].drop_duplicates()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 dupes[["email"]].drop_duplicates()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/series.py:1153, in Series.__getitem__(self, key)
#    1150     key = np.asarray(key, dtype=bool)
#    1151     return self._get_rows_with_mask(key)
# -> 1153 return self._get_with(key)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/series.py:1194, in Series._get_with(self, key)
#    1191         return self.iloc[key]
#    1193 # handle the dup indexing case GH#4246
# -> 1194 return self.loc[key]
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexing.py:1420, in _LocIndexer._getitem_axis(self, key, axis)
#    1417     if hasattr(key, "ndim") and key.ndim > 1:
#    1418         raise ValueError("Cannot index with multidimensional key")
# -> 1420     return self._getitem_iterable(key, axis=axis)
#    1422 # nested tuple slicing
#    1423 if is_nested_tuple(key, labels):
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexing.py:1360, in _LocIndexer._getitem_iterable(self, key, axis)
#    1357 self._validate_key(key, axis)
#    1359 # A collection of keys
# -> 1360 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1361 return self.obj._reindex_with_indexers(
#    1362     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1363 )
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexing.py:1558, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1555 ax = self.obj._get_axis(axis)
#    1556 axis_name = self.obj._get_axis_name(axis)
# -> 1558 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1560 return keyarr, indexer
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['email'], dtype='object')] are in the [index]"

# %%
df2.duplicated().sum()   # Count duplicates
# Out:
# np.int64(2)

# %% [markdown]
# ### Drop duplicates
# > DataFrame.drop_duplicates(subset=None, *, keep='first', inplace=False, ignore_index=False)

# %%
df2.drop_duplicates()         # Keep first occurrence
# Out:
#    ID Name
# 0   1    A
# 1   2    B
# 3   3    C
# 4   4    D

# %%
df2.drop_duplicates(keep='last')  # Keep last occurrence
# Out:
#    ID Name
# 0   1    A
# 2   2    B
# 3   3    C
# 5   4    D

# %%
df2.drop_duplicates(keep=False)  # Drop all duplicates.
# Out:
#    ID Name
# 0   1    A
# 3   3    C

# %%
df2.drop_duplicates(subset=['Name'])  # Check only specific column
# Out:
#    ID Name
# 0   1    A
# 1   2    B
# 3   3    C
# 4   4    D

# %% [markdown]
# ## 3. Handling Inconsistent Data
# > Handling values that are not uniform

# %%
df3 = pd.DataFrame({
    'City': ['delhi', 'Delhi ', 'MUMBAI', 'mumbai ', 'Bangalore']
})
df3
# Out:
#         City
# 0      delhi
# 1     Delhi
# 2     MUMBAI
# 3    mumbai
# 4  Bangalore

# %% [markdown]
# ### Strip extra spaces

# %%
df3['City'] = df3['City'].str.strip()
df3
# Out:
#         City
# 0      delhi
# 1      Delhi
# 2     MUMBAI
# 3     mumbai
# 4  Bangalore

# %% [markdown]
# ### Make consistent case

# %%
df3['City'] = df3['City'].str.title()   # First letter uppercase
df3
# Out:
#         City
# 0      Delhi
# 1      Delhi
# 2     Mumbai
# 3     Mumbai
# 4  Bangalore

# %%
df3['City'] = df3['City'].str.lower()   # all lowercase
df3
# Out:
#         City
# 0      delhi
# 1      delhi
# 2     mumbai
# 3     mumbai
# 4  bangalore

# %%
df3['City'] = df3['City'].str.upper()   # all uppercase
df3
# Out:
#         City
# 0      DELHI
# 1      DELHI
# 2     MUMBAI
# 3     MUMBAI
# 4  BANGALORE

# %% [markdown]
# ## 4. Detecting Outliers
# > Handling values that are way off

# %%
df4 = pd.DataFrame({
    'Salary': [30000, 40000, 50000, 1000000]   # 1M looks like an outlier
})
df4

# Simple rule: Z-score or IQR can be used (advanced part)
# Out:
#     Salary
# 0    30000
# 1    40000
# 2    50000
# 3  1000000

# %%
df4.describe()   # Spot extreme values
# Out:
#                Salary
# count        4.000000
# mean    280000.000000
# std     480069.439422
# min      30000.000000
# 25%      37500.000000
# 50%      45000.000000
# 75%     287500.000000
# max    1000000.000000
